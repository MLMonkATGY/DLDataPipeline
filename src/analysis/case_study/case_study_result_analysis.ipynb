# %%
import pandas as pd

# %%
caseStudyDf = pd.read_csv("/home/alextay96/Desktop/all_workspace/new_workspace/DLDataPipeline/data/case_study/case_study_3/case_study_result.csv")

# %%
labelErrorDf = caseStudyDf[caseStudyDf["remarks"] == "label error"]
labelErrorByPartDf = labelErrorDf.groupby(["part"])["CaseID"].count().reset_index().rename(columns={"CaseID" : "count"})
labelErrorByPartDf.sort_values(by="count", ascending=False, inplace=True)
labelErrorByPartDf["ratio"] = labelErrorByPartDf["count"] / len(caseStudyDf["CaseID"].unique())
labelErrorByPartDf
# Out:
#                 part  count     ratio
# 2       bumper_front     12  0.400000
# 11            grille      9  0.300000
# 12       headlamp_lh      9  0.300000
# 3        bumper_rear      8  0.266667
# 13       headlamp_rh      7  0.233333
# 7             engine      6  0.200000
# 8    fender_front_lh      6  0.200000
# 1             bonnet      5  0.166667
# 14  rear_compartment      4  0.133333
# 10       front_panel      3  0.100000
# 9    fender_front_rh      3  0.100000
# 18      tail_lamp_rh      3  0.100000
# 5      door_front_rh      2  0.066667
# 6       door_rear_lh      2  0.066667
# 17      tail_lamp_lh      1  0.033333
# 19  windscreen_front      1  0.033333
# 0   air_conditioning      1  0.033333
# 16   rear_quarter_lh      1  0.033333
# 15        rear_panel      1  0.033333
# 4      door_front_lh      1  0.033333
# 20   windscreen_rear      1  0.033333

# %%
predErrorDf = caseStudyDf[caseStudyDf["remarks"] == "error"]
predErrorByPartDf = predErrorDf.groupby(["part", "fp", "fn"])["CaseID"].count().reset_index().rename(columns={"CaseID" : "count"})
predErrorByPartDf.sort_values(by="count", ascending=False, inplace=True)
predErrorByPartDf["ratio"] = predErrorByPartDf["count"] / len(caseStudyDf["CaseID"].unique())
predErrorByPartDf
# Out:
#             part  fp  fn  count     ratio
# 7         engine   1   0      5  0.166667
# 2   bumper_front   1   0      4  0.133333
# 3    bumper_rear   1   0      3  0.100000
# 6   door_rear_rh   1   0      3  0.100000
# 0         bonnet   0   1      2  0.066667
# 12   headlamp_rh   1   0      2  0.066667
# 11   headlamp_lh   1   0      1  0.033333
# 15  tail_lamp_rh   1   0      1  0.033333
# 14  tail_lamp_lh   1   0      1  0.033333
# 13    rear_panel   1   0      1  0.033333
# 8    front_panel   0   1      1  0.033333
# 10        grille   1   0      1  0.033333
# 9         grille   0   1      1  0.033333
# 1         bonnet   1   0      1  0.033333
# 5   door_rear_rh   0   0      1  0.033333
# 4   door_rear_lh   1   0      1  0.033333
# 16         wheel   1   0      1  0.033333

# %%
tempDf = caseStudyDf[caseStudyDf["remarks"] == "label error"]
countDf = tempDf.groupby("CaseID")["remarks"].count().reset_index().rename(columns={
    "remarks" : "label_error_count"
})
countDf["after_repair_img"] = countDf["label_error_count"].apply(lambda x : x > 2)
countDf[countDf["after_repair_img"] == True]
# Out:
#       CaseID  label_error_count  after_repair_img
# 1   10228504                  4              True
# 2   10229726                  3              True
# 3   10231429                  4              True
# 4   10284983                  3              True
# 5   10293939                  4              True
# 7   10353034                  8              True
# 8   10485749                  3              True
# 9   10618351                  3              True
# 10  10983278                  4              True
# 11  11019580                  4              True
# 14  11741614                  5              True
# 15  11746258                  6              True
# 17  11947625                  3              True
# 18  12093743                  3              True
# 19  12393479                  5              True
# 21  12628126                  7              True
# 23  12801046                  3              True

# %%
afterRepairError = 7 / 30
afterRepairError
# Out:
# 0.23333333333333334

# %%
labelErrorButCorrectDf = caseStudyDf[(caseStudyDf["remarks"] == "label error") & (caseStudyDf["pred"] == caseStudyDf["gt"] )]
labelErrorButCorrectByPartDf = labelErrorButCorrectDf.groupby(["part"])["CaseID"].count().reset_index().rename(columns={"CaseID" : "count"})
labelErrorButCorrectByPartDf.sort_values(by="count", ascending=False, inplace=True)
labelErrorButCorrectByPartDf["ratio"] = labelErrorButCorrectByPartDf["count"] / len(caseStudyDf["CaseID"].unique())
labelErrorButCorrectByPartDf
# Out:
#                part  count     ratio
# 0      bumper_front      6  0.200000
# 5            grille      4  0.133333
# 1       bumper_rear      2  0.066667
# 6       headlamp_lh      2  0.066667
# 7       headlamp_rh      2  0.066667
# 8  rear_compartment      2  0.066667
# 2     door_front_rh      1  0.033333
# 3            engine      1  0.033333
# 4       front_panel      1  0.033333

# %%
labelErrorButIncorrectDf = caseStudyDf[(caseStudyDf["remarks"] == "label error") & (caseStudyDf["pred"] != caseStudyDf["gt"] )]
labelErrorButIncorrectByPartDf = labelErrorButIncorrectDf.groupby(["part"])["CaseID"].count().reset_index().rename(columns={"CaseID" : "count"})
labelErrorButIncorrectByPartDf.sort_values(by="count", ascending=False, inplace=True)
labelErrorButIncorrectByPartDf["ratio"] = labelErrorButIncorrectByPartDf["count"] / len(caseStudyDf["CaseID"].unique())
labelErrorButIncorrectByPartDf
# Out:
#                 part  count     ratio
# 12       headlamp_lh      7  0.233333
# 2       bumper_front      6  0.200000
# 3        bumper_rear      6  0.200000
# 8    fender_front_lh      6  0.200000
# 7             engine      5  0.166667
# 1             bonnet      5  0.166667
# 11            grille      5  0.166667
# 13       headlamp_rh      5  0.166667
# 18      tail_lamp_rh      3  0.100000
# 9    fender_front_rh      3  0.100000
# 10       front_panel      2  0.066667
# 6       door_rear_lh      2  0.066667
# 14  rear_compartment      2  0.066667
# 16   rear_quarter_lh      1  0.033333
# 19  windscreen_front      1  0.033333
# 17      tail_lamp_lh      1  0.033333
# 0   air_conditioning      1  0.033333
# 15        rear_panel      1  0.033333
# 5      door_front_rh      1  0.033333
# 4      door_front_lh      1  0.033333
# 20   windscreen_rear      1  0.033333
