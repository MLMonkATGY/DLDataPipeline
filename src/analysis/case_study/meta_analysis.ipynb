# %%
import pandas as pd

# %%
caseStudyDf = pd.read_csv("/home/alextay96/Desktop/all_workspace/new_workspace/DLDataPipeline/data/case_study/case_study_2/case_study_result.csv")

# %%
labelErrorDf = caseStudyDf[caseStudyDf["remarks"] == "label error"]
labelErrorByPartDf = labelErrorDf.groupby(["part"])["CaseID"].count().reset_index().rename(columns={"CaseID" : "count"})
labelErrorByPartDf.sort_values(by="count", ascending=False, inplace=True)
labelErrorByPartDf["ratio"] = labelErrorByPartDf["count"] / len(caseStudyDf["CaseID"].unique())
labelErrorByPartDf
# Out:
#                 part  count     ratio
# 7             grille      7  0.233333
# 9        headlamp_rh      6  0.200000
# 1       bumper_front      5  0.166667
# 8        headlamp_lh      5  0.166667
# 2        bumper_rear      4  0.133333
# 4    fender_front_lh      4  0.133333
# 3             engine      3  0.100000
# 0             bonnet      2  0.066667
# 5    fender_front_rh      2  0.066667
# 13             wheel      2  0.066667
# 6        front_panel      1  0.033333
# 10  rear_compartment      1  0.033333
# 11      tail_lamp_lh      1  0.033333
# 12      tail_lamp_rh      1  0.033333
# 14   windscreen_rear      1  0.033333

# %%
predErrorDf = caseStudyDf[caseStudyDf["remarks"] == "error"]
predErrorByPartDf = predErrorDf.groupby(["part", "fp", "fn"])["CaseID"].count().reset_index().rename(columns={"CaseID" : "count"})
predErrorByPartDf.sort_values(by="count", ascending=False, inplace=True)
predErrorByPartDf["ratio"] = predErrorByPartDf["count"] / len(caseStudyDf["CaseID"].unique())
predErrorByPartDf
# Out:
#                 part  fp  fn  count     ratio
# 2        bumper_rear   1   0     11  0.366667
# 0       bumper_front   1   0      7  0.233333
# 7             engine   1   0      7  0.233333
# 3      door_front_lh   1   0      6  0.200000
# 5       door_rear_lh   1   0      4  0.133333
# 10            grille   1   0      3  0.100000
# 8    fender_front_lh   1   0      3  0.100000
# 14             wheel   1   0      2  0.066667
# 6       door_rear_rh   1   0      1  0.033333
# 1        bumper_rear   0   1      1  0.033333
# 9        front_panel   1   0      1  0.033333
# 4      door_front_rh   1   0      1  0.033333
# 11       headlamp_lh   1   0      1  0.033333
# 12      tail_lamp_lh   1   0      1  0.033333
# 13      tail_lamp_rh   1   0      1  0.033333
# 15  windscreen_front   1   0      1  0.033333
# 16   windscreen_rear   1   0      1  0.033333

# %%
tempDf = caseStudyDf[caseStudyDf["remarks"] == "label error"]
countDf = tempDf.groupby("CaseID")["remarks"].count().reset_index().rename(columns={
    "remarks" : "label_error_count"
})
countDf["after_repair_img"] = countDf["label_error_count"].apply(lambda x : x > 2)
countDf[countDf["after_repair_img"] == True]
# Out:
#       CaseID  label_error_count  after_repair_img
# 6   10353034                  5              True
# 13  11746258                  3              True
# 16  12093743                  3              True
# 19  12628126                  4              True

# %%
afterRepairError = 4 / 30
